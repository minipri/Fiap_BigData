# %% [markdown]
# <a href="https://colab.research.google.com/github/minipri/Fiap_BigData/blob/main/SHIFT/desafio/baba/predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
from google.colab import files
df = pd.read_csv("https://raw.githubusercontent.com/diogenesjusto/FIAP/master/SHIFT/desafio/baba/BABA.csv", )

treino = df.iloc[0:365,]
teste = df.iloc[366:396,]

y_treino = treino['venda']
x_treino = treino[['outmg']]
x_teste = teste[['outmg']]

mod = LinearRegression()
mod.fit(x_treino, y_treino)
prev = mod.predict(x_teste) # Substitui teste['desconto'] pelo resultado do predict

#pd.DataFrame(prev).to_csv('predict.csv')
#files.download('predict.csv')

# %%
# Função para atribuir o valor 1 se maior que 200, caso contrário, 0
def atribuir_valor(valor):
    if valor > 200000:
        return 1
    else:
        return 0

# Criar a nova coluna com base na função atribuir_valor
df['outvenda'] = df['venda'].apply(atribuir_valor)

# Exibir o resultado
print(df)
# Out:
#      Unnamed: 0    X      date     mes        weekday    margem       venda  \
# 0             1    1  20140801  agosto    sexta-feira  0.406111  110042.460
# 1             2    2  20140802  agosto         sabado  0.416022   58377.320
# 2             3    3  20140803  agosto        domingo  0.431993   64635.390
# 3             4    4  20140804  agosto  segunda-feira  0.409216  140417.321
# 4             5    5  20140805  agosto    terca-feira  0.449648  149700.286
# ..          ...  ...       ...     ...            ...       ...         ...
# 391         392  392  20150827  agosto   quinta-feira  0.451562         NaN
# 392         393  393  20150828  agosto    sexta-feira  0.472608         NaN
# 393         394  394  20150829  agosto         sabado  0.385612         NaN
# 394         395  395  20150830  agosto        domingo  0.495615         NaN
# 395         396  396  20150831  agosto  segunda-feira  0.391486         NaN
#
#          desconto  outdesc  outmg  outvenda
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  396 non-null    int64
#  1   X           396 non-null    int64
#  2   date        396 non-null    int64
#  3   mes         396 non-null    object
#  4   weekday     396 non-null    object
#  5   margem      396 non-null    float64
#  6   venda       365 non-null    float64
#  7   desconto    396 non-null    float64
#  8   outdesc     396 non-null    int64
#  9   outmg       396 non-null    int64
#  10  outvenda    396 non-null    int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 34.2+ KB

# %%
# Configurando o gráfico
plt.plot(df['X'], df['venda'], marker='o', linestyle='-', color='blue')
plt.title('Evolução de Vendas')
plt.xlabel('Dia')
plt.ylabel('Venda')

# Exibindo o gráfico
plt.show()

# %%
# Configurando o gráfico
plt.plot(df['X'], df['margem'], marker='o', linestyle='-', color='blue')
plt.title('Evolução de Vendas')
plt.xlabel('Dia')
plt.ylabel('Margem')

# Exibindo o gráfico
plt.show()

# %%
# Configurando o gráfico
plt.plot(df['X'], df['outdesc'], marker='o', linestyle='-', color='blue')
plt.title('Evolução de Vendas')
plt.xlabel('Dia')
plt.ylabel('Margem')

# Exibindo o gráfico
plt.show()

# %%
# Configurando o gráfico
plt.plot(df['X'], df['outmg'], marker='o', linestyle='-', color='blue')
plt.title('Evolução de Vendas')
plt.xlabel('Dia')
plt.ylabel('OutDesc')

# Exibindo o gráfico
plt.show()

# %%
# Gráfico de dispersão
df.plot.scatter(x='venda', y='desconto')
# Out:
# <Axes: xlabel='venda', ylabel='desconto'>

# %%
treino = df.iloc[0:365,]
teste = df.iloc[366:396,]

y_treino = treino['venda']
x_treino = treino[['desconto']]
x_teste = teste[['desconto']]

mod = LinearRegression()
mod.fit(x_treino, y_treino)
prev = mod.predict(x_teste) # Substitui teste['desconto'] pelo resultado do predict

pd.DataFrame(prev).to_csv('predict.csv')
#files.download('predict.csv')
